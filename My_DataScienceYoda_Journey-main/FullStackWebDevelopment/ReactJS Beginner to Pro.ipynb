# %% [markdown]
# ## TOC: <a id=0-b ></a>
# * [Found three best resource for reactJS quick learning](#1-b)
# * [Udemy Course "React - The Complete Guide (incl Hooks, React Router, Redux)" by Maximilian Schwarzmüller](#2-b)
#   * [Section2: Javascript refresher](#3-b)
#   * [Section 3: React basics and working with components ](#4-b)

# %% [markdown]
# # 📅 Calendar 14 July 2021

# %% [markdown]
# # Found three best resource for reactJS quick learning <a id=1-b ></a>
# 1. W3 Schools react JS [Link](9https://www.w3schools.com/react/default.asp)
# 2. SudheerJ Git react 300+ interview questions [Link](https://github.com/sudheerj/reactjs-interview-questions)
# 3. Udemy Course "React - The Complete Guide (incl Hooks, React Router, Redux)" by Maximilian Schwarzmüller [Link](https://www.udemy.com/course/react-the-complete-guide-incl-redux/)
#
# [TOC](#0-b)

# %% [markdown]
# # Udemy Course "React - The Complete Guide (incl Hooks, React Router, Redux)" by Maximilian Schwarzmüller  <a id=2-b ></a>
# [TOC](#0-b)

# %% [markdown]
# ## Good Links:
# * Discord Academind react community https://discord.com/channels/622033978047725582/633290456566071297
# * Online link to run Web developement code https://jsbin.com/?js,console
# * History of Java script and ECMA Script 2,3 (1999),5(2009),6(2015),7(2016),8(2017),9(2018) https://madasamy.medium.com/javascript-brief-history-and-ecmascript-es6-es7-es8-features-673973394df4

# %% [markdown]
# ## Section 2: JavaScript Refresher <a id=3-b ></a>
# [TOC](#0-b)

# %% [markdown]
# ### const vs var vs let

# %% [markdown]
# ```js
# function printMyName(name) {
#   element.text(name);
# }
# printMyName('Ash')
#
#
# const printMyNamee = (name) => {
#   element.text(name);
# }
# printMyNamee('She')
#
#
# const multiply = (num1,num2) => num1*num2;
# element.text(multiply(4,7))
#
#
# // "Ash"
# //"She"
# // 28
# ```

# %% [markdown]
# ### Classes in Javascript and inheritance

# %% [markdown]
# ``` js
# class Human {
#   constructor() {
#     this.gender = 'Male';
#     this.surname = 'Shetty';
#   }
#
#   printGender() {
#     element.text(this.gender);
#   }
#
#   printSurname() {
#     element.text(this.surname);
#   }
#
# }
#
#
# class Person extends Human {
#   constructor() {
#     super();
#     this.name = 'Max';
#     this.surname = 'Jackson';
#   }
#
#   printName(){
#     element.text(this.name);
#   }
# }
#
# const individual = new Person();
# individual.printName();
# individual.printGender();
# individual.printSurname();
#
# // output https://jsbin.com/parezulize/edit?js,console
# // "Max"
# // "Male"
# // "Jackson"
# ```

# %% [markdown]
# # 📅 Calendar 15 July 2021

# %% [markdown]
# ### Using next generation JS ES7 syntax for class properties and class functions

# %% [markdown]
# ``` js
#
# class Human {
#     gender = 'Male';
#     surname = 'Shetty';
#
#   printGender = () => {
#     console.log(this.gender);
#   }
#
#   printSurname = () => {
#     console.log(this.surname);
#   }
#
# }
#
#
# class Person extends Human {
#     this.name = 'Max';
#     this.surname = 'Jackson';
#
#   printName = () => {
#     console.log(this.name);
#   }
# }
#
# const individual = new Person();
# individual.printName();
# individual.printGender();
# individual.printSurname();
#
# // output https://jsbin.com/parezulize/edit?js,console
# // "Max"
# // "Male"
# // "Jackson"
# ```

# %% [markdown]
# ### Spread and rest operators

# %% [markdown]
# Spread and rest operators are represented by three dots **...**
#
# Spread: Used to split up array elements OR object properties
# Rest: used to merge a list of function arguments into an array

# %% [markdown]
# ```js
#
#
# // Spread examples with arrays
# k = [1,2,3]
# L = [...k,8]
# console.log(k)
# console.log(L)
# // [1, 2, 3]
# // [1, 2, 3, 8]
#
# // Spread examples with object
# k = {'ash':2}
# L = {...k,'she':1}
# console.log(k)
# console.log(L)
# // [object Object] {
# //   ash: 2
# // }
# // [object Object] {
# //   ash: 2,
# //   she: 1
# // }
#
# // Rest examples with
# const filter = (...args) => {
#   return args.filter(el => el ===  1);
# }
#
# console.log(filter(1,1,3));
# // [1,1]
# ```

# %% [markdown]
# ### Destructuring
#
# Similar to spread but here you can easily etract array elements or object properties and store them in variables

# %% [markdown]
# ```js
# // array destructuring
# [a,b] = ['Hello','Hi']
# console.log(a)
# console.log(b)
#
# //object destructuring
# {name} = {name:'ash', d:'she'}
# console.log(name)
# ```

# %% [markdown]
# ### Primitive type and reference type

# %% [markdown]
# ```js
# // Primitive: Creates a real copy of numbers
#
# const number = 1121;
# const number1 = number;
# console.log(number1)
# // 1121
#
# // Reference type: Object and arrays dont create a copy but add pointers
#
# const person = {ash: '123'};
# const person1 = person;
# person.ash = '456';
# console.log(person1)
#
# // [object Object] {
# //   ash: "456"
# // }
#
#
# // How to avoid Reference type:Use spread ... for Object and arrays
#
# const aeasdf = {ash: '123'};
# const xvb = {  ...aeasdf};
# aeasdf.ash = '456';
# // console.log(xvb)
# // [object Object] {
# //   ash: "123"
# // }
# ```

# %% [markdown]
# ### Refreshing array functions

# %% [markdown]
# ```js
# // map functions
# const arr1 = [1,2,3];
# const arr2 = arr1.map((num) => num*2);
# const arr3 = arr1.map((num) => {
#   return num*3;
# });
# console.log(arr1) // [1, 2, 3]
# console.log(arr2) // [2, 4, 6]
# console.log(arr3) // [3, 6, 9]
# ```

# %% [markdown]
# Particularly important in this course are:
#
# map()  => https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/map
# find()  => https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/find
# findIndex()  => https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/findIndex
# filter()  => https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/filter
# reduce()  => https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/Reduce?v=b
# concat()  => https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/concat?v=b
# slice()  => https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/slice
# splice()  => https://developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global_Objects/Array/splice

# %% [markdown]
# ## Section 3: React basics and working with components <a id=4-b ></a>
# [TOC](#0-b)

# %% [markdown]
# * React is declarative. It decides how to edit DOM based on desired target state specified
# * create-react-app : helps easy building react app, allowing to preview applicaiton locally in machine and browser automatically updates. There reacct-app also helps to traonformation and optimazation.
# * Node.js is used to run JS script outside browser. But react runs inside browser so we ideally dont need node.js. But the create-react-app needs node.js. So we install node.js.
# * setup crete-react-app by going through this documentation [link](https://reactjs.org/docs/create-a-new-react-app.html)

# %% [markdown]
# Notes:
# * in react JS components function and components files are named with CapWords naming conventions. Since React treats lower case as HTML tags and Capwords as custom components
# * In react each component must return only one root. It doesnot allow to pass more than one root in return of each components
# * Props allows react components to be reusabel. Props usually is an object which is array of key value pairs, where key is typical attribute and value is attributes value.
# * Component splitting
# * props.children to have component that provides for example reusable component formatting. This allows to create wrapper components.
