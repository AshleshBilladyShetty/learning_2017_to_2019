# %% [markdown]
# # Motivation
#
# **Andrew NG:** How did your understanding of AI change over these years?
# **Greoffrey Hinton reply highlights:** I guess a lot of my intellectual history has been around back propogation. To begin in mid 80s  we were using it for discriminative learning it was working well I then decided by the early 90s that actualy most human learnignis going to be unsupervised learning and I got much more interested in unsupervised learning and thats when I worked on things like  wake-sleep algorithm. In the long run I think unsupervised learning is going to be absolutely crucial.
#
# **Andrew NG:** I think many of the senior people in deeplearning including myself remain very excited about it none of us really have almost any idea how to do it yet may be you do, I odnt feel I do.
# **Geoffrey Hinton reply highlights:** Variational encoders and generative  Adversarial net also seem to be really a nice idea.
#
# **Andrew NG:** What about sparsity and slow features which are two of the other principles for unsupervised learning?
# **Geoffrey Hinton reply highlights:** Basic principles behind your model or anything. you take your measurements and you apply your non linear transformations to your measurements until you get to a representation  as a state vector in which the action is linear so you dont pretend its linear like you do with common filters  but find a transformation from the observables to the underlying variables where linear operations like matrix multiplication on the underlying variables will do the work.
#
# **Andrew NG:** What advise you want to give to global audience  who wants to get into Deep Learning?
# **Geoffrey Hinton reply highlights:** Read the literature but dont read too much of it. Read a little bit of literature and notice that something you think is that everbody is doing wrong and then how to do it right. people might might not believe it but keep at it. Principle to keep at it: Either your intuition is good or not. If your intuition is good you should follow it and eventully you will be successfull and if your intuition is not good it doesnot matter what you do.

# %% [markdown]
# # Some interseting things that I learnt researching on unsupervised training using DNN

# %% [markdown]
# Good book to gain in depth knowledge of DNN?
# A book by Ian Goodfellow and Yoshua Bengio and Aaron Courville
# http://www.deeplearningbook.org/

# %% [markdown]
# **What are few kew features of unsupervised learning with DNN**
# Unsupervised learning: https://www.youtube.com/watch?v=p4Vh_zMw-HQ
#     * only uses $x^{(t)}$ for learning
#     * automatically extracts meaningful features for your data
#     * lverages the availability of unlabeled data. Very useful when we have huge amount of unlabeled data w.r.t labaeled data
#     * Objective funcition looks like $ - log p(x^{(t)})$

# %% [markdown]
# # RBM
# **RBM Restricted Boltzman MAchine**
# * Good refernce
# https://deeplearning4j.org/restrictedboltzmannmachine
# https://www.youtube.com/watch?v=puux7KZQfsE
# https://stats.stackexchange.com/questions/114385/what-is-the-difference-between-convolutional-neural-networks-restricted-boltzma
#
# * Automatically find pattern in data by reconstructing input. We have 2 layer visible layer and hidden layer.
# * It has restricted in the name because there is no two node in the same layer share a connection
# * In forward pass RBM takes inputs and translates them to numbers that encode the inputs. In the bacwards pass it takes the set of numbers and translates them back to form the reconstructed inputs.
# * Three steps are repeated over and over again throught the training process
#     *  forward pass
#     * backward pass
#     * RBM uses KL divergence to compare the accuracy if generative accuracy
# * RBM can extract features
# * RBM shares similar idea, but uses stochastic approach. Instead of deterministic (e.g. logistic or ReLU) it uses stochastic units with particular (usually binary of Gaussian) distribution. Learning procedure consists of several steps of Gibbs sampling (propagate: sample hiddens given visibles; reconstruct: sample visibles given hiddens; repeat) and adjusting the weights to minimize reconstruction error.
# * Intuition behind RBMs is that there are some visible random variables (e.g. film reviews from different users) and some hidden variables (like film genres or other internal features), and the task of training is to find out how these two sets of variables are actually connected to each other (more on this example may be found here).

# %%
from IPython.display import Image
Image('C:\\Users\\Ashlesh B Shetty\\Desktop\\ZZ\\JobSearch\\GitHubRepos' + 
      '\\DeepLearning-ArtificialIntelligence_ScikitLearn-TensorFlow\\images\\RBM.png', 
      width = 500)

# %% [markdown]
# # DBN  Deep Belief Net
# **DBN  Deep Belief Net**
# https://www.youtube.com/watch?v=E2Mt_7qked0
# * it is a stacked RBM, where hidden layer of one RBM is visble layer of the one above it
# * **IMPORTANT NOTE** Important note about DBN is that each RBM layer learns the **ENTIRE** input. In other models line Convolutional NN early layers detect simple patterns and later layer recombine them. like earlier layer will detect edges and later layers will combine them to form facial features.
# * After the initial training the RBM have created  a model that can detect inherent patterns. To finish training we need to introduce the labels to the patterns  and fine tune the net with supervised learning.
# * **ADVANTAGE:** To do this we need a small set of labeled samples so that features and patterns can be associated with a name. The weights and bisaes are slighly changed resulting in small changes in nets perception of the patterns and often a small increase in the accuracy. There fore set of labelled data can be small relative to the original dataset which as we discussed is extremely helpful in real world applications

# %%
Image('C:\\Users\\Ashlesh B Shetty\\Desktop\\ZZ\\JobSearch\\GitHubRepos' + 
      '\\DeepLearning-ArtificialIntelligence_ScikitLearn-TensorFlow\\images\\DeepBeliefNet.png', 
      width = 700)

# %% [markdown]
# # Autoencoders
# **Autoencoders**
# https://www.youtube.com/watch?v=s96mYcicbpE&index=10&list=PLjJh1vlSEYgvGod9wWiydumYl8hOXixNu
# * having access to most important data features gives you a lot of flexibility when you start applying labels
# * Examples of types of autoencoders denoising, contractive etc.
# * Autoencoders is a neural net that takes a set of typically unlabeled inputs and after encodeing them tries to reconstruct them as accurately as possible. As a result of this net must decide which of the data features are most important essentially acting as feature extraction engine.
# * Autoencoder are typically shallow. Input, hidden and output layer.
# * The two steps encoding and decoding. typically the same weight that are used toencode feature are used to encode a feature  in the hidden layer are used toreconstruct an image in the output layer.
# * Autoencoders are trained using backpropogation using a metric loss.
# * Deep auto encoders are extemely useful for dimensioanlity reduction
# * Deep autoencoders performs better than PCA.

# %%
Image('C:\\Users\\Ashlesh B Shetty\\Desktop\\ZZ\\JobSearch\\GitHubRepos' + 
      '\\DeepLearning-ArtificialIntelligence_ScikitLearn-TensorFlow\\images\\Autoencoders.png', 
      width = 500)

# %% [markdown]
# **International conference of learning representatives** To be updated with cutting edge papers in DNN  field follow proceedings of ICLR
# https://iclr.cc/

# %% [markdown]
# # GAN Generalized Adversarial Networks
# **Generalized Adversarial Networks**: Generative network and discriminator netowrk
# https://www.analyticsvidhya.com/blog/2017/06/introductory-generative-adversarial-networks-gans/
#  * A class of artificial intelligence algorithms used in unsupervised machine learning, implemented by a system of two neural networks contesting with each other in a zero-sum game framework.
#  * **Minimax Game** is a decision rule used in decision theory, game theory, statistics and philosophy for minimizing the possible loss for a worst case (maximum loss) scenario. Originally formulated for two-player zero-sum game theory
#     * Zerosum game :a situation in which each participant's gain or loss of utility is exactly balanced by the losses or gains of the utility of the other participants. If the total gains of the participants are added up and the total losses are subtracted, they will sum to zero
#  * One network generates candidates and the other evaluates them. Typically, the generative network learns to map from a latent space to a particular data distribution of interest, while the discriminative network discriminates between instances from the true data distribution and candidates produced by the generator. The generative network's training objective is to increase the error rate of the discriminative network

# %%
Image('C:\\Users\\Ashlesh B Shetty\\Desktop\\ZZ\\JobSearch\\GitHubRepos' + 
      '\\DeepLearning-ArtificialIntelligence_ScikitLearn-TensorFlow\\images\\GAN.png', 
      width = 800)

# %% [markdown]
# **Challenges with GAN**
# * The most important roadblock while training a GAN is stability. Both generator and discriminator are fighting against each other to get one step ahead of the other. Also, they are dependent on each other for efficient training. If one of them fails, the whole system fails. So you have to make sure they don’t explode.
# * Problem with Counting: GANs fail to differentiate how many of a particular object should occur at a location.
# * Problems with Perspective: GANs fail to adapt to 3D objects. It doesn’t understand perspective, i.e.difference between frontview and backview
# * Problems with Global Structures: Same as the problem with perspective, GANs do not understand a holistic structure.

# %% [markdown]
# # Variational Autoencoders
# http://kvfrans.com/variational-autoencoders-explained/

# %% [markdown]
# ### Why we need Variational autoencoder
# This addresses few main problems that GAN has
# * First, the images are generated off some arbitrary noise. If you wanted to generate a picture with specific features, there's no way of determining which initial noise values would produce that picture, other than searching over the entire distribution.
# * Second, a generative adversarial model only discriminates between "real" and "fake" images. There's no constraints that an image of a cat has to look like a cat. This leads to results where there's no actual object in a generated image, but the style just looks like picture.

# %% [markdown]
# ### How is Variational Autoencoders different from Autoencoders
# If we save the encoded vector of an image, we can reconstruct it later by passing it into the decoder portion. What we have is the standard autoencoder.
#
# We're trying to build a generative model here, not just a fuzzy data structure that can "memorize" images. We can't generate anything yet, since we don't know how to create latent vectors other than encoding them from images.
#
# There's a simple solution here. We add a constraint on the encoding network, that forces it to generate latent vectors that roughly follow a unit gaussian distribution. It is this constraint that separates a variational autoencoder from a standard one.
#
# Generating new images is now easy: all we need to do is sample a latent vector from the unit gaussian and pass it into the decoder.
#
# In practice, there's a tradeoff between how accurate our network can be and how close its latent variables can match the unit gaussian distribution

# %% [markdown]
# ### Loss Calculation in Variational Autoencoders; Generative Loss i.e. MSE  + Latent Loss i.e KL Divergence

# %% [markdown]
# * the generative loss, which is a mean squared error that measures how accurately the network reconstructed the images
# * the latent loss, which is the KL divergence that measures how closely the latent variables match a unit gaussian.
#
# In order to optimize the KL divergence, we need to apply a simple reparameterization trick: instead of the encoder generating a vector of real values, it will generate a vector of means and a vector of standard deviations.This lets us calculate KL divergence.
#
# When we're calculating loss for the decoder network, we can just sample from the standard deviations and add the mean, and use that as our latent vector

# %% [markdown]
# ### Autoencoders

# %%
Image('C:\\Users\\Ashlesh B Shetty\\Desktop\\ZZ\\JobSearch\\GitHubRepos' + 
      '\\DeepLearning-ArtificialIntelligence_ScikitLearn-TensorFlow\\images\\v ariationalautoencoder1.png', 
      width = 800)

# %% [markdown]
# ### Variational Autoencoders

# %%
Image('C:\\Users\\Ashlesh B Shetty\\Desktop\\ZZ\\JobSearch\\GitHubRepos' + 
      '\\DeepLearning-ArtificialIntelligence_ScikitLearn-TensorFlow\\images\\variationalautoencoder2.png', 
      width = 800)

# %% [markdown]
# ## Effect of adding a constraint on the encoding network, that forces it to generate latent vectors that roughly follow a unit gaussian distribution
#
# 1. **Allows us to genaraterandom latent variables**
#     * When we're calculating loss for the decoder network, we can just sample from the standard deviations and add the mean, and use that as our latent vector
# 2. **This constraint also improves the genrealization**
#     * Let's say you were given a bunch of pairs of real numbers between [0, 10], along with a name. For example, 5.43 means apple, and 5.44 means banana. When someone gives you the number 5.43, you know for sure they are talking about an apple. We can essentially encode infinite information this way, since there's no limit on how many different real numbers we can have between [0, 10].
#     * However, what if there was a gaussian noise of one added every time someone tried to tell you a number? Now when you receive the number 5.43, the original number could have been anywhere around [4.4 ~ 6.4], so the other person could just as well have meant banana (5.44).
#     * The greater standard deviation on the noise added, the less information we can pass using that one variable.
#     * Now we can apply this same logic to the latent variable passed between the encoder and decoder. The more efficiently we can encode the original image, the higher we can raise the standard deviation on our gaussian until it reaches one.
#     * This constraint forces the encoder to be very efficient, creating information-rich latent variables. This improves generalization, so latent variables that we either randomly generated, or we got from encoding non-training images, will produce a nicer result when decoded.

# %% [markdown]
# **Variational Autoencoders**
#
# **Advantage** Since they follow an encoding-decoding scheme, we can compare generated images directly to the originals, which is not possible when using a GAN.
#
# **Disadvantage** A downside to the VAE is that it uses direct mean squared error instead of an adversarial network, so the network tends to produce more blurry images

# %% [markdown]
# # Attention and Memory in Deep learning
#
# **Attention**
# Attention Mechanisms in Neural Networks are (very) loosely based on the visual attention mechanism found in humans. Human visual attention is well-studied and while there exist different models, all of them essentially come down to being able to focus on a certain region of an image with “high resolution” while perceiving the surrounding image in “low resolution”, and then adjusting the focal point over time
#
# Recurrent neural network is a type of Attention model and slight variation in it LSTM has a good performance with respect to  memory
